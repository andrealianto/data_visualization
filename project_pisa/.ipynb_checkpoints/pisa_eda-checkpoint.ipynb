# %% [markdown]
# # PISA 2012 Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np

# %pylab inline
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
filename = 'pisa2012.csv'

# load csv file
pisa = pd.read_csv(filename)

# %%
pisa.describe()
# Out:
#           Unnamed: 0      SUBNATIO       SCHOOLID        STIDSTD  \
# count  485490.000000  4.854900e+05  485490.000000  485490.000000
# mean   242745.500000  4.315457e+06     240.152197    6134.066201
# std    140149.035432  2.524434e+06     278.563016    6733.144944
# min         1.000000  8.000000e+04       1.000000       1.000000
# 25%    121373.250000  2.030000e+06      61.000000    1811.000000
# 50%    242745.500000  4.100000e+06     136.000000    3740.000000
# 75%    364117.750000  6.880000e+06     291.000000    7456.000000
# max    485490.000000  8.580000e+06    1471.000000   33806.000000
#
#              ST01Q01        ST02Q01        ST03Q01        ST03Q02  \
# count  485490.000000  485438.000000  485490.000000  485490.000000
# mean        9.813323       2.579260       6.558512    1996.070061
# std         3.734726       2.694013       3.705244       0.255250
# min         7.000000       1.000000       1.000000    1996.000000
# 25%         9.000000       1.000000       4.000000    1996.000000
# 50%        10.000000       1.000000       7.000000    1996.000000
# 75%        10.000000       3.000000       9.000000    1996.000000
# max        96.000000      25.000000      99.000000    1997.000000
#
#              ST06Q01       ST115Q01      ...             W_FSTR74  \
# count  457994.000000  479269.000000      ...        485490.000000
# mean        6.148963       1.265356      ...            50.844201
# std         0.970693       0.578992      ...           120.684726
# min         4.000000       1.000000      ...             0.292900
# 25%         6.000000       1.000000      ...             4.660300
# 50%         6.000000       1.000000      ...            13.637700
# 75%         7.000000       1.000000      ...            41.233500
# max        16.000000       4.000000      ...          2476.566800
#
#             W_FSTR75       W_FSTR76       W_FSTR77       W_FSTR78  \
# count  485490.000000  485490.000000  485490.000000  485490.000000
# mean       51.020378      50.943149      50.685275      51.019842
# std       122.946533     121.170883     119.267686     122.981541
# min         0.292900       0.292900       0.292900       0.292900
# 25%         4.664800       4.643100       4.667000       4.675200
# 50%        13.698900      13.611700      13.672100      13.731100
# 75%        41.512500      41.695200      41.097300      41.189600
# max      4155.283000    3743.450100    3232.163700    3904.868100
#
#             W_FSTR79       W_FSTR80       WVARSTRR       VAR_UNIT  \
# count  485490.000000  485490.000000  485490.000000  485490.000000
# mean       50.540724      50.721164      40.013920       1.531189
# std       119.479516     119.799018      22.951264       0.539759
# min         0.292900       0.292900       1.000000       1.000000
# 25%         4.651850       4.660300      20.000000       1.000000
# 50%        13.582000      13.600200      40.000000       2.000000
# 75%        41.290925      41.356000      60.000000       2.000000
# max      3607.478300    3412.174100      80.000000       3.000000
#
#           SENWGT_STU
# count  485490.000000
# mean        0.140054
# std         0.137864
# min         0.000500
# 25%         0.037800
# 50%         0.145200
# 75%         0.199900
# max         5.095500
#
# [8 rows x 268 columns]

# %%
pisa.head()
# Out:
#    Unnamed: 0      CNT  SUBNATIO  STRATUM      OECD       NC  SCHOOLID  \
# 0           1  Albania     80000  ALB0006  Non-OECD  Albania         1
# 1           2  Albania     80000  ALB0006  Non-OECD  Albania         1
# 2           3  Albania     80000  ALB0006  Non-OECD  Albania         1
# 3           4  Albania     80000  ALB0006  Non-OECD  Albania         1
# 4           5  Albania     80000  ALB0006  Non-OECD  Albania         1
#
#    STIDSTD  ST01Q01  ST02Q01   ...     W_FSTR75  W_FSTR76 W_FSTR77 W_FSTR78  \
# 0        1       10      1.0   ...      13.7954   13.9235  13.1249  13.1249
# 1        2       10      1.0   ...      13.7954   13.9235  13.1249  13.1249
# 2        3        9      1.0   ...      12.7307   12.7307  12.7307  12.7307
# 3        4        9      1.0   ...      12.7307   12.7307  12.7307  12.7307
# 4        5        9      1.0   ...      12.7307   12.7307  12.7307  12.7307
#
#    W_FSTR79 W_FSTR80 WVARSTRR VAR_UNIT SENWGT_STU  VER_STU
# 0    4.3389  13.0829       19        1     0.2098  22NOV13
# 1    4.3389  13.0829       19        1     0.2098  22NOV13
# 2    4.2436  12.7307       19        1     0.1999  22NOV13
# 3    4.2436  12.7307       19        1     0.1999  22NOV13
# 4    4.2436  12.7307       19        1     0.1999  22NOV13
#
# [5 rows x 636 columns]

# %% [markdown]
# ## 1. Create score table

# %%
# Create score table
score_columns = ['CNT', 'OECD',
                 'PV1MATH', 'PV2MATH', 'PV3MATH', 'PV4MATH', 'PV5MATH',
                 'PV1READ', 'PV2READ', 'PV3READ', 'PV4READ', 'PV5READ',
                 'PV1SCIE', 'PV2SCIE', 'PV3SCIE', 'PV4SCIE', 'PV5SCIE',
                 'W_FSTUWT']

# subset original dataframe
pisaScores = pisa[score_columns].copy()
pisaScores = pisaSelect.fillna(0)

# %%
pisaScores.head()
# Out:
#        CNT      OECD   PV1MATH   PV2MATH   PV3MATH   PV4MATH   PV5MATH  \
# 0  Albania  Non-OECD  406.8469  376.4683  344.5319  321.1637  381.9209
# 1  Albania  Non-OECD  486.1427  464.3325  453.4273  472.9008  476.0165
# 2  Albania  Non-OECD  533.2684  481.0796  489.6479  490.4269  533.2684
# 3  Albania  Non-OECD  412.2215  498.6836  415.3373  466.7472  454.2842
# 4  Albania  Non-OECD  381.9209  328.1742  403.7311  418.5309  395.1628
#
#     PV1READ   PV2READ   PV3READ      ...       PV1READ_temp  PV2READ_temp  \
# 0  249.5762  254.3420  406.8496      ...        2223.624112   2266.085483
# 1  406.2936  349.8975  400.7334      ...        3619.913459   3117.446766
# 2  401.2100  404.3872  387.7067      ...        3405.109391   3432.074605
# 3  547.3630  481.4353  461.5776      ...        4645.524517   4085.989535
# 4  311.7707  141.7883  293.5015      ...        2646.029108   1203.371481
#
#    PV3READ_temp  PV4READ_temp  PV5READ_temp  PV1SCIE_temp  PV2SCIE_temp  \
# 0   3624.867196   1565.463941   1947.621632   3044.418339   3642.600864
# 1   3570.374301   3294.371821   3534.988933   4891.307142   4201.735285
# 2   3290.505534   3661.282320   3405.109391   4240.700881   3639.227742
# 3   3917.455249   3607.351043   4005.093044   3723.117633   4087.166695
# 4   2490.976581   2315.700991   2207.838438   3068.619640   2340.521515
#
#    PV3SCIE_temp  PV4SCIE_temp  PV5SCIE_temp
# 0   3102.574862   3277.044431   3501.363212
# 1   4201.735285   3952.492789   4052.189431
# 2   4177.387963   4351.498274   4240.700881
# 3   3810.173213   4023.853778   3620.234461
# 4   3163.589440   3424.755330   3583.038048
#
# [5 rows x 33 columns]

# %%
# Function to aggregate math, reading, and science scores by weighted average calculation
def aggregate_score(df):
    df['PV1MATH_temp'] = df.PV1MATH * df.W_FSTUWT
    df['PV2MATH_temp'] = df.PV2MATH * df.W_FSTUWT
    df['PV3MATH_temp'] = df.PV3MATH * df.W_FSTUWT
    df['PV4MATH_temp'] = df.PV4MATH * df.W_FSTUWT
    df['PV5MATH_temp'] = df.PV5MATH * df.W_FSTUWT
    
    df['PV1READ_temp'] = df.PV1READ * df.W_FSTUWT
    df['PV2READ_temp'] = df.PV2READ * df.W_FSTUWT
    df['PV3READ_temp'] = df.PV3READ * df.W_FSTUWT
    df['PV4READ_temp'] = df.PV4READ * df.W_FSTUWT
    df['PV5READ_temp'] = df.PV5READ * df.W_FSTUWT

    df['PV1SCIE_temp'] = df.PV1SCIE * df.W_FSTUWT
    df['PV2SCIE_temp'] = df.PV2SCIE * df.W_FSTUWT
    df['PV3SCIE_temp'] = df.PV3SCIE * df.W_FSTUWT
    df['PV4SCIE_temp'] = df.PV4SCIE * df.W_FSTUWT
    df['PV5SCIE_temp'] = df.PV5SCIE * df.W_FSTUWT
    
    grouped = df.groupby(['CNT', 'OECD']).sum().reset_index()
    grouped.head()
    
    grouped['PV1MATH_AVE'] = grouped.PV1MATH_temp / grouped.W_FSTUWT
    grouped['PV2MATH_AVE'] = grouped.PV2MATH_temp / grouped.W_FSTUWT
    grouped['PV3MATH_AVE'] = grouped.PV3MATH_temp / grouped.W_FSTUWT
    grouped['PV4MATH_AVE'] = grouped.PV4MATH_temp / grouped.W_FSTUWT
    grouped['PV5MATH_AVE'] = grouped.PV5MATH_temp / grouped.W_FSTUWT
    grouped['MATHAVE'] = (grouped.PV1MATH_AVE + grouped.PV2MATH_AVE + grouped.PV3MATH_AVE + 
                          grouped.PV4MATH_AVE + grouped.PV5MATH_AVE)/5
    
    grouped['PV1READ_AVE'] = grouped.PV1READ_temp / grouped.W_FSTUWT
    grouped['PV2READ_AVE'] = grouped.PV2READ_temp / grouped.W_FSTUWT
    grouped['PV3READ_AVE'] = grouped.PV3READ_temp / grouped.W_FSTUWT
    grouped['PV4READ_AVE'] = grouped.PV4READ_temp / grouped.W_FSTUWT
    grouped['PV5READ_AVE'] = grouped.PV5READ_temp / grouped.W_FSTUWT
    grouped['READAVE'] = (grouped.PV1READ_AVE + grouped.PV2READ_AVE + grouped.PV3READ_AVE + 
                          grouped.PV4READ_AVE + grouped.PV5READ_AVE)/5
    
    grouped['PV1SCIE_AVE'] = grouped.PV1SCIE_temp / grouped.W_FSTUWT
    grouped['PV2SCIE_AVE'] = grouped.PV2SCIE_temp / grouped.W_FSTUWT
    grouped['PV3SCIE_AVE'] = grouped.PV3SCIE_temp / grouped.W_FSTUWT
    grouped['PV4SCIE_AVE'] = grouped.PV4SCIE_temp / grouped.W_FSTUWT
    grouped['PV5SCIE_AVE'] = grouped.PV5SCIE_temp / grouped.W_FSTUWT
    grouped['SCIEAVE'] = (grouped.PV1SCIE_AVE + grouped.PV2SCIE_AVE + grouped.PV3SCIE_AVE + 
                          grouped.PV4SCIE_AVE + grouped.PV5SCIE_AVE)/5
    
    return grouped
    
grouped = aggregate_score(pisaSelect)

# Drop unnecessary columns
wanted_columns = ['CNT', 'OECD', 'MATHAVE', 'READAVE', 'SCIEAVE']
pisaScore_grouped = grouped[wanted_columns].copy()
pisaScore_grouped.head()
# Out:
#          CNT      OECD     MATHAVE     READAVE     SCIEAVE
# 0    Albania  Non-OECD  394.329333  393.964252  397.373214
# 1  Argentina  Non-OECD  388.431710  395.979123  405.632005
# 2  Australia      OECD  504.150766  511.803998  521.494746
# 3    Austria      OECD  505.540743  489.609335  505.781247
# 4    Belgium      OECD  514.745239  509.108049  505.457459

# %% [markdown]
# ## 2. Create out-of-school-study table

# %%
# Create out-of-school-study table
out_of_school_columns = ['CNT',
                         'ST57Q01', 'ST57Q02', 'ST57Q03', 'ST57Q04', 'ST57Q05', 'ST57Q06']

# subset original dataframe
pisaOut = pisa[out_of_school_columns].copy()
pisaOut = pisaOut.fillna(0)

pisaOut=pisaOut.rename(columns = {'ST57Q01':'OOS_homework', 'ST57Q02':'OOS_guided_homework',
                                  'ST57Q03':'OOS_personal_tutor', 'ST57Q04': 'OOS_commercial_company',
                                  'ST57Q05':'OOS_parents', 'ST57Q06':'OOS_computer'})

pisaOut_grouped = pisaOut.groupby('CNT').mean().reset_index()
pisaOut_grouped.head()
# Out:
#          CNT  OOS_homework  OOS_guided_homework  OOS_personal_tutor  \
# 0    Albania      2.285895             1.665823            1.323002
# 1  Argentina      2.117468             0.808565            0.679926
# 2  Australia      3.535944             0.724467            0.266004
# 3    Austria      2.941746             0.606309            0.244374
# 4    Belgium      3.507386             0.419332            0.207863
#
#    OOS_commercial_company  OOS_parents  OOS_computer
# 0                1.378242     1.819313      2.227915
# 1                0.493230     0.713947      1.072952
# 2                0.196533     0.628824      0.694220
# 3                0.140484     0.660778      0.645846
# 4                0.119344     0.425032      0.544492

# %% [markdown]
# ## 3. Merge score and out-of-school-study tables

# %%
# Merge score table with out-of-school-study table
pisaMerged = pd.merge(pisaScore_grouped, pisaOut_grouped, how = 'left', on = 'CNT')
pisaMerged.head()
# Out:
#          CNT      OECD     MATHAVE     READAVE     SCIEAVE  OOS_homework  \
# 0    Albania  Non-OECD  394.329333  393.964252  397.373214      2.285895
# 1  Argentina  Non-OECD  388.431710  395.979123  405.632005      2.117468
# 2  Australia      OECD  504.150766  511.803998  521.494746      3.535944
# 3    Austria      OECD  505.540743  489.609335  505.781247      2.941746
# 4    Belgium      OECD  514.745239  509.108049  505.457459      3.507386
#
#    OOS_guided_homework  OOS_personal_tutor  OOS_commercial_company  \
# 0             1.665823            1.323002                1.378242
# 1             0.808565            0.679926                0.493230
# 2             0.724467            0.266004                0.196533
# 3             0.606309            0.244374                0.140484
# 4             0.419332            0.207863                0.119344
#
#    OOS_parents  OOS_computer
# 0     1.819313      2.227915
# 1     0.713947      1.072952
# 2     0.628824      0.694220
# 3     0.660778      0.645846
# 4     0.425032      0.544492

# %% [markdown]
# ## 4. Drop non-country rows

# %%
# Check number of countries to see if there is any duplication
len(pisaMerged)
# Out:
# 68

# %% [markdown]
# According to the dataset description, only 65 countries participated in PISA 2012.
#
# A quick check of the CSV file revealed that in the dataset, USA is split into 3 regions, and Russsian Federation is split into 2 regions. We will aggregate Connecticut, Florida, and Massachusetts into USA. We will also aggregate Perm(Russian Federation) and Russian Federation into Russia.

# %%
# Drop non-country rows (Connecticut, Massachusetts, Florida, Perm)
idxUSA = pisaMerged[pisaMerged['CNT'].str.contains("USA")].index.tolist()
idxRussia = pisaMerged[pisaMerged['CNT'].str.contains("Perm")].index.tolist()
dropped_idx = idxUSA + idxRussia
pisaMerged = pisaMerged.drop(dropped_idx)
len(pisaMerged)
# Out:
# 64

# %% [markdown]
# ## 5. Export to CSV file

# %%
# output csv file
pisaMerged.to_csv('pisa2012_cleaned.csv',  index=False)
